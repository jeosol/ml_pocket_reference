# %% [markdown]
# ## Chapter5

# %%
# !pip install configparser mysqlclient
# Out:
# ...
#      |████████████████████████████████| 87 kB 745 kB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/onwunalu/.pyenv/versions/3.9.0/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-tgdlj51h/mysqlclient_040f6a447fb246c587f8c7c86d19099e/setup.py'"'"'; __file__='"'"'/tmp/pip-install-tgdlj51h/mysqlclient_040f6a447fb246c587f8c7c86d19099e/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-8sb8tqtb
#        cwd: /tmp/pip-install-tgdlj51h/mysqlclient_040f6a447fb246c587f8c7c86d19099e/
#   Complete output (15 lines):
#   /bin/sh: mysql_config: command not found
#   /bin/sh: mariadb_config: command not found
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import janitor
from sklearn import (ensemble, preprocessing, tree)
from sklearn.metrics import (auc, confusion_matrix, roc_auc_score, roc_curve)
from sklearn.model_selection import (train_test_split, StratifiedKFold)
from yellowbrick.classifier import(ConfusionMatrix, ROCAUC)
from yellowbrick.model_selection import (LearningCurve)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-3839325035e0> in <module>
#       1 import matplotlib.pyplot as plt
#       2 import pandas as pd
# ----> 3 import janitor
#       4 from sklearn import (ensemble, preprocessing, tree)
#       5 from sklearn.metrics import (auc, confusion_matrix, roc_auc_score, roc_curve)
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/janitor.py in <module>
#       4 """
#       5 import argparse
# ----> 6 import ConfigParser
#       7
#       8 from flask import Flask, send_from_directory
#
# ModuleNotFoundError: No module named 'ConfigParser'

# %% [markdown]
# ## Gather Data

# %%
url = ("titanic3.xls")

# %%
df = pd.read_excel(url)
orig_df = df

# %% [markdown]
# ## Cleaning Data
#
# - We can use generic tools like pandas and specialized tools like pyjanitor to help with cleaning data

# %% [markdown]
# ## Column Names
#
# - having python friendly column names makes attributes access possible
# - pyjanitor clean_names function will return a DataFrame with columns in lowercase and spaces replaces by underscores

# %%
import janitor as jn
Xbad = pd.DataFrame({ "A": [1, None, 3], " sales numbers ": [20.0, 30.0, None]})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d0e44c9bd046> in <module>
# ----> 1 import janitor as jn
#       2 Xbad = pd.DataFrame({ "A": [1, None, 3], " sales numbers ": [20.0, 30.0, None]})
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/janitor.py in <module>
#       4 """
#       5 import argparse
# ----> 6 import ConfigParser
#       7
#       8 from flask import Flask, send_from_directory
#
# ModuleNotFoundError: No module named 'ConfigParser'

# %%
df.isna().any().any()
# Out:
# True
